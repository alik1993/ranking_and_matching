# %% [markdown]
# # ideal

# %%
import math
import pickle
import random
from typing import List, Tuple

import numpy as np
import torch
from catboost.datasets import msrank_10k
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from tqdm.auto import tqdm


class Solution:
    def __init__(self, n_estimators: int = 100, lr: float = 0.5, ndcg_top_k: int = 10,
                 subsample: float = 0.6, colsample_bytree: float = 0.9,
                 max_depth: int = 7, min_samples_leaf: int = 8):
        self._prepare_data()
        self.num_input_features = self.X_train.shape[1]
        self.num_train_objects = self.X_train.shape[0]
        self.num_test_objects = self.X_test.shape[0]

        self.features_to_choice = int(
            self.num_input_features * colsample_bytree)
        self.objects_to_choice = int(self.num_train_objects * subsample)

        self.ndcg_top_k = ndcg_top_k
        self.n_estimators = n_estimators
        self.lr = lr
        self.max_depth = max_depth
        self.min_samples_leaf = min_samples_leaf

        self.trees = None
        self.trees_feat_idxs = None
        self.best_ndcg = -1
        self.best_iter_idx = -1

    def _get_data(self) -> List[np.array]:
        train_df, test_df = msrank_10k()

        X_train = train_df.drop([0, 1], axis=1).values
        y_train = train_df[0].values
        query_ids_train = train_df[1].values.astype(int)

        X_test = test_df.drop([0, 1], axis=1).values
        y_test = test_df[0].values
        query_ids_test = test_df[1].values.astype(int)

        return [X_train, y_train, query_ids_train, X_test, y_test, query_ids_test]

    def _prepare_data(self) -> None:
        (X_train, y_train, self.query_ids_train,
            X_test, y_test, self.query_ids_test) = self._get_data()

        X_train = self._scale_features_in_query_groups(
            X_train, self.query_ids_train)
        X_test = self._scale_features_in_query_groups(
            X_test, self.query_ids_train)

        self.X_train = torch.FloatTensor(X_train)
        self.X_test = torch.FloatTensor(X_test)

        self.ys_train = torch.FloatTensor(y_train).reshape(-1, 1)
        self.ys_test = torch.FloatTensor(y_test).reshape(-1, 1)

    def _scale_features_in_query_groups(self, inp_feat_array: np.array,
                                        inp_query_ids: np.array) -> np.array:
        for cur_id in np.unique(inp_query_ids):
            mask = inp_query_ids == cur_id
            tmp_array = inp_feat_array[mask]
            scaler = StandardScaler()
            inp_feat_array[mask] = scaler.fit_transform(tmp_array)

        return inp_feat_array

    def _train_one_tree(self, cur_tree_idx: int,
                        train_preds: torch.FloatTensor
                        ) -> Tuple[DecisionTreeRegressor, np.array]:
        lambdas = torch.zeros(self.num_train_objects, 1)
        for cur_id in np.unique(self.query_ids_train):
            train_mask = self.query_ids_train == cur_id
            lambda_update = self._compute_lambdas(
                self.ys_train[train_mask], train_preds[train_mask])
            if any(torch.isnan(lambda_update)):
                lambda_update = torch.zeros_like(lambda_update)
            lambdas[train_mask] = lambda_update

        tree = DecisionTreeRegressor(
            max_depth=self.max_depth, min_samples_leaf=self.min_samples_leaf, random_state=cur_tree_idx)

        this_tree_feats = np.random.choice(
            list(range(self.num_input_features)), self.features_to_choice, replace=False)
        this_tree_objs = np.random.choice(
            list(range(self.num_train_objects)), self.objects_to_choice, replace=False)

        tree.fit(
            self.X_train[this_tree_objs.reshape(-1)
                         ][:, this_tree_feats].numpy(),
            -lambdas[this_tree_objs.reshape(-1), :].numpy()
        )

        return tree, this_tree_feats

    def _calc_data_ndcg(self, queries_list: np.array,
                        true_labels: torch.FloatTensor, preds: torch.FloatTensor) -> float:
        ndcgs = []
        for cur_id in np.unique(queries_list):
            mask = queries_list == cur_id
            cur_ndcg = self._ndcg_k(
                true_labels[mask], preds[mask], self.ndcg_top_k)
            if np.isnan(cur_ndcg):
                ndcgs.append(0)
                continue
            ndcgs.append(cur_ndcg)
        return np.mean(ndcgs)

    def fit(self):
        np.random.seed(0)
        self.trees = []
        self.trees_feat_idxs = []
        self.best_ndcg = -1
        self.best_iter_idx = -1

        train_preds = torch.zeros(self.num_train_objects, 1)
        test_preds = torch.zeros(self.num_test_objects, 1)

        train_ndcgs, test_ndcgs = [], []

        p_bar = tqdm(range(self.n_estimators))
        for cur_tree_idx in p_bar:
            tree, this_tree_feats = self._train_one_tree(
                cur_tree_idx, train_preds)
            self.trees.append(tree)
            self.trees_feat_idxs.append(this_tree_feats)

            cur_tree_train_data = self.X_train[:, this_tree_feats].numpy()
            train_preds += self.lr * \
                torch.FloatTensor(tree.predict(
                    cur_tree_train_data)).reshape(-1, 1)
            train_ndcg = self._calc_data_ndcg(
                self.query_ids_train, self.ys_train, train_preds)

            cur_tree_test_data = self.X_test[:, this_tree_feats].numpy()
            test_preds += self.lr * \
                torch.FloatTensor(tree.predict(
                    cur_tree_test_data)).reshape(-1, 1)
            test_ndcg = self._calc_data_ndcg(
                self.query_ids_test, self.ys_test, test_preds)

            if self.best_ndcg < test_ndcg:
                self.best_ndcg = test_ndcg
                self.best_iter_idx = cur_tree_idx

            train_ndcgs.append(train_ndcg)
            test_ndcgs.append(test_ndcg)
            p_bar.set_description_str(
                f'Test nDCG@{self.ndcg_top_k}={round(test_ndcg, 5)}')

        cut_idx = self.best_iter_idx + 1
        self.trees = self.trees[:cut_idx]
        self.trees_feat_idxs = self.trees_feat_idxs[:cut_idx]

    def predict(self, data: torch.FloatTensor) -> torch.FloatTensor:
        preds = torch.zeros(data.shape[0], 1)
        for cur_tree_idx in range(len(self.trees)):
            tree = self.trees[cur_tree_idx]
            feat_idx = self.trees_feat_idxs[cur_tree_idx]
            tmp_preds = tree.predict(data[:, feat_idx].numpy())
            preds += self.lr * torch.FloatTensor(tmp_preds).reshape(-1, 1)

        return preds

    def _compute_ideal_dcg(self, ys_true: torch.FloatTensor) -> float:
        def dcg(ys_true, ys_pred):
            _, argsort = torch.sort(ys_pred, descending=True, dim=0)
            ys_true_sorted = ys_true[argsort]
            ret = 0
            for i, l in enumerate(ys_true_sorted, 1):
                ret += (2 ** l - 1) / np.log2(1 + i)
            return ret
        ideal_dcg = dcg(ys_true, ys_true)
        return ideal_dcg

    def _compute_lambdas(self, y_true, y_pred):
        # рассчитаем нормировку, IdealDCG
        ideal_dcg = self._compute_ideal_dcg(y_true)
        N = 1 / ideal_dcg

        # рассчитаем порядок документов согласно оценкам релевантности
        _, rank_order = torch.sort(y_true, descending=True, axis=0)
        rank_order += 1

        with torch.no_grad():
            # получаем все попарные разницы скоров в батче
            pos_pairs_score_diff = 1.0 + torch.exp((y_pred - y_pred.t()))

            # поставим разметку для пар, 1 если первый документ релевантнее
            # -1 если второй документ релевантнее
            Sij = self._compute_labels_in_batch(y_true)
            # посчитаем изменение gain из-за перестановок
            gain_diff = self._compute_gain_diff(y_true)

            # посчитаем изменение знаменателей-дискаунтеров
            decay_diff = (1.0 / torch.log2(rank_order + 1.0)) - \
                (1.0 / torch.log2(rank_order.t() + 1.0))
            # посчитаем непосредственное изменение nDCG
            delta_ndcg = torch.abs(N * gain_diff * decay_diff)
            # посчитаем лямбды
            lambda_update = (0.5 * (1 - Sij) - 1 /
                             pos_pairs_score_diff) * delta_ndcg
            lambda_update = torch.sum(lambda_update, dim=1, keepdim=True)

            return lambda_update

    def _compute_labels_in_batch(self, y_true):
        rel_diff = y_true - y_true.t()
        pos_pairs = (rel_diff > 0).type(torch.float32)
        neg_pairs = (rel_diff < 0).type(torch.float32)
        Sij = pos_pairs - neg_pairs
        return Sij

    def _compute_gain_diff(self, y_true):
        gain_diff = torch.pow(2.0, y_true) - torch.pow(2.0, y_true.t())
        return gain_diff

    def _ndcg_k(self, ys_true, ys_pred, ndcg_top_k) -> float:
        def dcg(ys_true, ys_pred):
            _, argsort = torch.sort(ys_pred, descending=True, dim=0)
            argsort = argsort[:ndcg_top_k]
            ys_true_sorted = ys_true[argsort]
            ret = 0
            for i, l in enumerate(ys_true_sorted, 1):
                ret += (2 ** l - 1) / math.log2(1 + i)
            return ret
        ideal_dcg = dcg(ys_true, ys_true)
        pred_dcg = dcg(ys_true, ys_pred)
        return (pred_dcg / ideal_dcg).item()

    def save_model(self, path: str):
        state = {
            'trees': self.trees,
            'trees_feat_idxs': self.trees_feat_idxs,
            'best_ndcg': self.best_ndcg,
            'lr': self.lr
        }
        f = open(path, 'wb')
        pickle.dump(state, f)

    def load_model(self, path: str):
        f = open(path, 'rb')
        state = pickle.load(f)
        self.trees = state['trees']
        self.trees_feat_idxs = state['trees_feat_idxs']
        self.best_ndcg = state['best_ndcg']
        self.lr = state['lr']

# %% [markdown]
# # me

# %%
import math
import pickle
import random
from typing import List, Tuple

import numpy as np
import torch
from catboost.datasets import msrank_10k
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from tqdm.auto import tqdm


class Solution:
    def __init__(self, n_estimators: int = 100, lr: float = 0.5, ndcg_top_k: int = 10,
                 subsample: float = 0.6, colsample_bytree: float = 0.9,
                 max_depth: int = 5, min_samples_leaf: int = 8):
        self._prepare_data()

        self.ndcg_top_k = ndcg_top_k
        self.n_estimators = n_estimators
        
        self.lr = lr
        self.max_depth = max_depth
        self.min_samples_leaf = min_samples_leaf
        self.subsample = subsample
        self.colsample_bytree = colsample_bytree
        
        self.lr = 0.2
        self.max_depth = 13
        self.min_samples_leaf = 13
        self.subsample = 0.25
        self.colsample_bytree = 0.85
                
    def _get_data(self) -> List[np.ndarray]:
        train_df, test_df = msrank_10k()

        X_train = train_df.drop([0, 1], axis=1).values
        y_train = train_df[0].values
        query_ids_train = train_df[1].values.astype(int)

        X_test = test_df.drop([0, 1], axis=1).values
        y_test = test_df[0].values
        query_ids_test = test_df[1].values.astype(int)

        return [X_train, y_train, query_ids_train, X_test, y_test, query_ids_test]

    def _prepare_data(self) -> None:
        (X_train, y_train, self.query_ids_train,
            X_test, y_test, self.query_ids_test) = self._get_data()

        self.X_train = self._scale_features_in_query_groups(X_train, self.query_ids_train)
        self.X_test = self._scale_features_in_query_groups(X_test, self.query_ids_test)

        self.ys_train = torch.FloatTensor(y_train).reshape(-1,1)
        self.ys_test = torch.FloatTensor(y_test).reshape(-1,1)

    def _scale_features_in_query_groups(self, inp_feat_array: np.ndarray,
                                        inp_query_ids: np.ndarray) -> np.ndarray:
        
        total_inp_scaled = np.empty((0, inp_feat_array.shape[1])) 
        
        total_ids_list = []
        
        for for_v in np.unique(inp_query_ids):
            ids_list = [i for i, v in enumerate(inp_query_ids) if v==for_v]
            
            scaler = StandardScaler()
            
            group_inp_scaled = scaler.fit_transform(inp_feat_array[ids_list])
                        
            total_inp_scaled = np.concatenate([total_inp_scaled, 
                                               group_inp_scaled])
    
            total_ids_list.append(ids_list)
        
        total_ids_list = [i for sl in total_ids_list for i in sl]
            
        sort_ind = np.argsort(total_ids_list)
        
        total_inp_scaled = torch.FloatTensor(total_inp_scaled[sort_ind])
     
        return total_inp_scaled
    
    def _train_one_tree(self, cur_tree_idx: int,
                        train_preds: torch.FloatTensor
                        ) -> Tuple[DecisionTreeRegressor, np.ndarray]:
        
        torch.manual_seed(cur_tree_idx)
        np.random.seed(cur_tree_idx)
        
        total_ids_list = []
        
        total_lambda = np.empty((0, 1)) 
        
        for train_id_cat in np.unique(self.query_ids_train):
            
            idx_list = [i for i, v in enumerate(self.query_ids_train) if v==train_id_cat]

            batch_ys = self.ys_train[idx_list]
            batch_pred = train_preds[idx_list]
            
            if len(batch_ys) > 0:
                total_lambda = np.concatenate([total_lambda, 
                                               self._compute_lambdas(batch_ys, batch_pred)])

                total_ids_list.append(idx_list)
            
        total_ids_list = [i for sl in total_ids_list for i in sl]
            
        sort_ind = np.argsort(total_ids_list)
        
        total_lambda = total_lambda[sort_ind]
            
        rows_cnt = self.X_train.shape[0]
        subsample_size = round(self.subsample * rows_cnt) # or int() # можно вынести в init
        rows_indices = np.random.choice(np.arange(rows_cnt), subsample_size, replace=False) 
        
        cols_cnt = self.X_train.shape[1]
        colsample_size = round(self.colsample_bytree * cols_cnt)
        cols_indices = np.random.choice(np.arange(cols_cnt), colsample_size, replace=False)
                
        X_sub = self.X_train[rows_indices][:, cols_indices]
        l_sub = total_lambda[rows_indices]
        
        dt_reg = DecisionTreeRegressor(max_depth=self.max_depth, min_samples_leaf=self.min_samples_leaf)
        dt_reg.fit(X_sub,l_sub)
                
        return dt_reg, cols_indices

    def _calc_data_ndcg(self, queries_list: np.ndarray,
                        true_labels: torch.FloatTensor, preds: torch.FloatTensor) -> float:
        
        ndcgs = []
        
        for query_cat in np.unique(queries_list):

            idx_list = [i for i, v in enumerate(queries_list) if v==query_cat]

            ys_cat = true_labels[idx_list]
            preds_cat = preds[idx_list]

            ndcg_score = self._ndcg_k(ys_cat, preds_cat, self.ndcg_top_k)
            
            ndcgs.append(ndcg_score)

        return np.mean(ndcgs)

    def fit(self):
        np.random.seed(0)
        train_preds = torch.zeros(len(self.X_train))
        test_preds = torch.zeros(len(self.X_test))
        self.trees = []
        best_ndcg = 0
        ndcg_val_list = []
        cols_indices_list = []
#         p_bar = tqdm(range(self.n_est))
#         p_bar.set_desctiption_str()
        for t in range(self.n_estimators):
            dt_reg, cols_indices = self._train_one_tree(t, train_preds)

            train_preds = train_preds - self.lr * dt_reg.predict(self.X_train[:,cols_indices])
        
            self.trees.append(dt_reg)
            
            test_preds = test_preds - self.lr * dt_reg.predict(self.X_test[:,cols_indices])
            
            curr_ndcg = self._calc_data_ndcg(self.query_ids_test, self.ys_test, test_preds)
            ndcg_val_list.append(curr_ndcg)
            if curr_ndcg > best_ndcg:
                best_ndcg = curr_ndcg
                
            cols_indices_list.append(cols_indices)
            
        if len(self.trees)>1:
            self.trees = self.trees[:ndcg_val_list.index(best_ndcg)]
            
        self.best_ndcg = best_ndcg
        
        self.ndcg_val_list = ndcg_val_list
        self.cols_indices_list = cols_indices_list
                  
    def predict(self, data: torch.FloatTensor) -> torch.FloatTensor:
        preds = torch.zeros(len(data))
        for ix, t in enumerate(self.trees):
            preds = preds - self.lr * t.predict(data[:, self.cols_indices_list[ix]])
        return preds

    def _compute_lambdas(self, y_true: torch.FloatTensor, y_pred: torch.FloatTensor) -> torch.FloatTensor:
        ideal_dcg = self.compute_ideal_dcg(y_true)

        N = 1 / ideal_dcg
        _, rank_order = torch.sort(y_true, descending=True, axis=0)
        rank_order += 1

        with torch.no_grad():
            pos_pairs_score_diff = 1.0 + torch.exp((y_pred - y_pred.t()))
            Sij = self.compute_labels_in_batch(y_true)
            gain_diff = self.compute_gain_diff(y_true)
            decay_diff = (1.0 / torch.log2(rank_order + 1.0)) - (1.0 / torch.log2(rank_order.t() + 1.0))
            delta_ndcg = torch.abs(N * gain_diff * decay_diff)
            lambda_update =  (0.5 * (1 - Sij) - 1 / pos_pairs_score_diff) * delta_ndcg
            lambda_update = torch.sum(lambda_update, dim=1, keepdim=True) # суммируем вдоль строчек

            return lambda_update

    def _ndcg_k(self, ys_true: torch.Tensor, ys_pred: torch.Tensor,
                ndcg_top_k: int) -> float:

        ys_ideal_true_sort, _ = torch.sort(ys_true, descending=True, dim=0)
    
        if ndcg_top_k:
            ys_ideal_true_sort = ys_ideal_true_sort[:ndcg_top_k]

        ideal_dcg = 0
        for ix, e in enumerate(ys_ideal_true_sort):
            ideal_dcg += self.compute_gain(float(e), gain_scheme="exp2")/math.log2(ix+2)
    
#         ideal_dcg = self.compute_ideal_dcg(ys_ideal_true_sort)
        
        dcg_ = self.dcg(ys_true, ys_pred, gain_scheme="exp2", top_k=ndcg_top_k)
                
        return dcg_/ideal_dcg
    
    def dcg(self, ys_true: torch.Tensor, ys_pred: torch.Tensor, gain_scheme: str, top_k: int) -> float:
        ys_pred_sort, sort_indices = torch.sort(ys_pred, descending=True, dim=0)
        ys_true_sort = ys_true[sort_indices] 
        
        if top_k:
            ys_true_sort = ys_true_sort[:top_k]
            
        dcg_ = 0
        for ix, e in enumerate(ys_true_sort):
            dcg_ += self.compute_gain(float(e), gain_scheme)/math.log2(ix+2)

        return dcg_
    
    def compute_ideal_dcg(self, ys_true: torch.Tensor, ndcg_scheme: str = 'exp2') -> float:
        ys_ideal_true_sort, _ = torch.sort(ys_true, descending=True, dim=0)

        ideal_dcg = 0
        for ix, e in enumerate(ys_ideal_true_sort):
            ideal_dcg += self.compute_gain(float(e), ndcg_scheme)/math.log2(ix+2)

        if ideal_dcg == 0:
            ideal_dcg = 1
            
        return ideal_dcg
    
    def compute_gain(self, y_value: float, gain_scheme: str) -> float:
        if gain_scheme=="const":
            return y_value
        elif gain_scheme=="exp2":
            # return 2**y_value - 1
            return pow(2, y_value) - 1
        else:
            return None
        
    def save_model(self, path: str):
        with open(path, 'wb') as f:
            pickle.dump([self.trees, self.cols_indices_list, self.lr], f)

    def load_model(self, path: str):
        with open(path, 'rb') as f:
            self.trees, self.cols_indices_list, self.lr = pickle.load(f)
            
    def compute_labels_in_batch(self, y_true):
        rel_diff = y_true - y_true.t()
        pos_pairs = (rel_diff > 0).type(torch.float32)
        neg_pairs = (rel_diff < 0).type(torch.float32)
        Sij = pos_pairs - neg_pairs
        return Sij

    def compute_gain_diff(self, y_true, gain_scheme = 'exp2'):
        if gain_scheme == "exp2":
            gain_diff = torch.pow(2.0, y_true) - torch.pow(2.0, y_true.t())
        elif gain_scheme == "diff":
            gain_diff = y_true - y_true.t()
        else:
            raise ValueError(f"{gain_scheme} method not supported")
        return gain_diff

# %%
s = Solution()

# %%
# s.lr = 0.5
# ndcg_top_k = 10,
# s.subsample = 0.9
# colsample_bytree = 0.9,
# max_depth = 5, 
# min_samples_leaf = 8

# %%
s.fit()

# %%
s.best_ndcg
# Out:
# 0.43199949666272697

# %%
s.save_model('output/model.bin')

# %%
s.load_model('output/model.bin')

# %%
test_preds = s.predict(s.X_test)

# %%
s._calc_data_ndcg(s.query_ids_test, s.ys_test, test_preds)
# Out:
# 0.4318346664243743

# %%
import hyperopt

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, rand, tpe, space_eval

# %%
#зададим пространство поиска
space = [hp.choice('lr', np.arange(0.05, 1, 0.05)), 
         hp.choice('subsample', np.arange(0.1, 1, 0.05)),
         hp.choice('colsample_bytree', np.arange(0.1, 1, 0.05)),
         hp.choice('max_depth', np.arange(3, 15, 2)),
         hp.choice('min_samples_leaf', np.arange(3, 15, 2))
        ]

#укажем objective-функцию
def f(args):
    s.lr, s.subsample, s.colsample_bytree, s.max_depth, s.min_samples_leaf = args
    s.fit()
    test_preds = s.predict(s.X_test)
    ndcg_test = s._calc_data_ndcg(s.query_ids_test, s.ys_test, test_preds)
    return -ndcg_test

trials = Trials()

best = fmin(f, space, algo = tpe.suggest, max_evals=150, trials=trials)
print ('TPE result: ', best)
# Out:
#  55%|█████▍    | 82/150 [1:39:52<1:22:49, 73.08s/trial, best loss: -0.4318346664243743]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-333-15ea02e60f2f> in <module>
#      17 trials = Trials()
#      18
# ---> 19 best = fmin(f, space, algo = tpe.suggest, max_evals=150, trials=trials)
#      20 print ('TPE result: ', best)
#
# ~/environments/albert/lib/python3.6/site-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     520             show_progressbar=show_progressbar,
#     521             early_stop_fn=early_stop_fn,
# --> 522             trials_save_file=trials_save_file,
#     523         )
#     524
#
# ~/environments/albert/lib/python3.6/site-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     697             show_progressbar=show_progressbar,
#     698             early_stop_fn=early_stop_fn,
# --> 699             trials_save_file=trials_save_file,
#     700         )
#     701
#
# ~/environments/albert/lib/python3.6/site-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     551
#     552     # next line is where the fmin is actually executed
# --> 553     rval.exhaust()
#     554
#     555     if return_argmin:
#
# ~/environments/albert/lib/python3.6/site-packages/hyperopt/fmin.py in exhaust(self)
#     354     def exhaust(self):
#     355         n_done = len(self.trials)
# --> 356         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     357         self.trials.refresh()
#     358         return self
#
# ~/environments/albert/lib/python3.6/site-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     290                 else:
#     291                     # -- loop over trials and do the jobs directly
# --> 292                     self.serial_evaluate()
#     293
#     294                 self.trials.refresh()
#
# ~/environments/albert/lib/python3.6/site-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#     168                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     169                 try:
# --> 170                     result = self.domain.evaluate(spec, ctrl)
#     171                 except Exception as e:
#     172                     logger.error("job exception: %s" % str(e))
#
# ~/environments/albert/lib/python3.6/site-packages/hyperopt/base.py in evaluate(self, config, ctrl, attach_attachments)
#     905                 print_node_on_error=self.rec_eval_print_node_on_error,
#     906             )
# --> 907             rval = self.fn(pyll_rval)
#     908
#     909         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-333-15ea02e60f2f> in f(args)
#      10 def f(args):
#      11     s.lr, s.subsample, s.colsample_bytree, s.max_depth, s.min_samples_leaf = args
# ---> 12     s.fit()
#      13     test_preds = s.predict(s.X_test)
#      14     ndcg_test = s._calc_data_ndcg(s.query_ids_test, s.ys_test, test_preds)
#
# <ipython-input-322-970b213570af> in fit(self)
#     164         cols_indices_list = []
#     165         for t in range(self.n_estimators):
# --> 166             dt_reg, cols_indices = self._train_one_tree(t, train_preds)
#     167
#     168             train_preds = train_preds - self.lr * dt_reg.predict(self.X_train[:,cols_indices])
#
# <ipython-input-322-970b213570af> in _train_one_tree(self, cur_tree_idx, train_preds)
#     133
#     134         dt_reg = DecisionTreeRegressor(max_depth=self.max_depth, min_samples_leaf=self.min_samples_leaf)
# --> 135         dt_reg.fit(X_sub,l_sub)
#     136
#     137         return dt_reg, cols_indices
#
# ~/environments/albert/lib/python3.6/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1254             sample_weight=sample_weight,
#    1255             check_input=check_input,
# -> 1256             X_idx_sorted=X_idx_sorted)
#    1257         return self
#    1258
#
# ~/environments/albert/lib/python3.6/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     392                                            min_impurity_split)
#     393
# --> 394         builder.build(self.tree_, X, y, sample_weight)
#     395
#     396         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
dict(zip(['lr','subsample', 'colsample_bytree', 'max_depth','min_samples_leaf'], 
         hyperopt.space_eval(space, trials.argmin)))
# Out:
# {'lr': 0.2,
#  'subsample': 0.25000000000000006,
#  'colsample_bytree': 0.8500000000000002,
#  'max_depth': 13,
#  'min_samples_leaf': 13}

# %%
best_trials = sorted(trials.trials, key=lambda x: x['result']['loss'], reverse=False)[20:40]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-337-c6f3ca85678c> in <module>
# ----> 1 best_trials = sorted(trials.trials, key=lambda x: x['result']['loss'], reverse=False)[20:40]
#
# <ipython-input-337-c6f3ca85678c> in <lambda>(x)
# ----> 1 best_trials = sorted(trials.trials, key=lambda x: x['result']['loss'], reverse=False)[20:40]
#
# KeyError: 'loss'

# %%
trials.trials
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': -0.36977544952521574, 'status': 'ok'},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [0],
#     'lr': [0],
#     'max_depth': [0],
#     'min_samples_leaf': [0],
#     'subsample': [0]},
#    'vals': {'colsample_bytree': [3],
#     'lr': [14],
#     'max_depth': [1],
#     'min_samples_leaf': [1],
#     'subsample': [11]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 45, 12, 842000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 46, 7, 90000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': -0.38172287350624196, 'status': 'ok'},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [1],
#     'lr': [1],
#     'max_depth': [1],
#     'min_samples_leaf': [1],
#     'subsample': [1]},
#    'vals': {'colsample_bytree': [3],
#     'lr': [15],
#     'max_depth': [4],
#     'min_samples_leaf': [1],
#     'subsample': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 46, 7, 96000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 46, 56, 666000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': -0.39845135234925005, 'status': 'ok'},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [2],
#     'lr': [2],
#     'max_depth': [2],
#     'min_samples_leaf': [2],
#     'subsample': [2]},
#    'vals': {'colsample_bytree': [13],
#     'lr': [14],
#     'max_depth': [3],
#     'min_samples_leaf': [4],
#     'subsample': [16]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 46, 56, 673000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 48, 55, 413000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': -0.40862389629714807, 'status': 'ok'},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [3],
#     'lr': [3],
#     'max_depth': [3],
#     'min_samples_leaf': [3],
#     'subsample': [3]},
#    'vals': {'colsample_bytree': [11],
#     'lr': [0],
#     'max_depth': [4],
#     'min_samples_leaf': [2],
#     'subsample': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 48, 55, 420000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 50, 3, 777000)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': -0.38200949283857616, 'status': 'ok'},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [4],
#     'lr': [4],
#     'max_depth': [4],
#     'min_samples_leaf': [4],
#     'subsample': [4]},
#    'vals': {'colsample_bytree': [8],
#     'lr': [3],
#     'max_depth': [0],
#     'min_samples_leaf': [0],
#     'subsample': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 50, 3, 788000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 50, 51, 62000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': -0.4078566158413062, 'status': 'ok'},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [5],
#     'lr': [5],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [5]},
#    'vals': {'colsample_bytree': [11],
#     'lr': [7],
#     'max_depth': [3],
#     'min_samples_leaf': [1],
#     'subsample': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 50, 51, 69000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 51, 40, 172000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': -0.4205515549054731, 'status': 'ok'},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [6],
#     'lr': [6],
#     'max_depth': [6],
#     'min_samples_leaf': [6],
#     'subsample': [6]},
#    'vals': {'colsample_bytree': [12],
#     'lr': [5],
#     'max_depth': [3],
#     'min_samples_leaf': [5],
#     'subsample': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 51, 40, 178000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 52, 50, 812000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': -0.36874192248671794, 'status': 'ok'},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [7],
#     'lr': [7],
#     'max_depth': [7],
#     'min_samples_leaf': [7],
#     'subsample': [7]},
#    'vals': {'colsample_bytree': [2],
#     'lr': [9],
#     'max_depth': [4],
#     'min_samples_leaf': [2],
#     'subsample': [9]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 52, 50, 818000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 53, 44, 625000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': -0.3965236483687955, 'status': 'ok'},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [8],
#     'lr': [8],
#     'max_depth': [8],
#     'min_samples_leaf': [8],
#     'subsample': [8]},
#    'vals': {'colsample_bytree': [11],
#     'lr': [12],
#     'max_depth': [3],
#     'min_samples_leaf': [0],
#     'subsample': [11]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 53, 44, 632000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 55, 6, 725000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': -0.3963395912702039, 'status': 'ok'},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [9],
#     'lr': [9],
#     'max_depth': [9],
#     'min_samples_leaf': [9],
#     'subsample': [9]},
#    'vals': {'colsample_bytree': [5],
#     'lr': [16],
#     'max_depth': [0],
#     'min_samples_leaf': [4],
#     'subsample': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 55, 6, 731000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 55, 52, 692000)},
#  {'state': 2,
#   'tid': 10,
#   'spec': None,
#   'result': {'loss': -0.35134112279499513, 'status': 'ok'},
#   'misc': {'tid': 10,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [10],
#     'lr': [10],
#     'max_depth': [10],
#     'min_samples_leaf': [10],
#     'subsample': [10]},
#    'vals': {'colsample_bytree': [1],
#     'lr': [2],
#     'max_depth': [1],
#     'min_samples_leaf': [0],
#     'subsample': [7]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 55, 52, 699000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 56, 37, 56000)},
#  {'state': 2,
#   'tid': 11,
#   'spec': None,
#   'result': {'loss': -0.4156180577599905, 'status': 'ok'},
#   'misc': {'tid': 11,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [11],
#     'lr': [11],
#     'max_depth': [11],
#     'min_samples_leaf': [11],
#     'subsample': [11]},
#    'vals': {'colsample_bytree': [13],
#     'lr': [10],
#     'max_depth': [4],
#     'min_samples_leaf': [3],
#     'subsample': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 56, 37, 62000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 57, 55, 485000)},
#  {'state': 2,
#   'tid': 12,
#   'spec': None,
#   'result': {'loss': -0.39123260540144644, 'status': 'ok'},
#   'misc': {'tid': 12,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [12],
#     'lr': [12],
#     'max_depth': [12],
#     'min_samples_leaf': [12],
#     'subsample': [12]},
#    'vals': {'colsample_bytree': [16],
#     'lr': [4],
#     'max_depth': [1],
#     'min_samples_leaf': [4],
#     'subsample': [17]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 57, 55, 496000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 19, 59, 30, 854000)},
#  {'state': 2,
#   'tid': 13,
#   'spec': None,
#   'result': {'loss': -0.40296374996151924, 'status': 'ok'},
#   'misc': {'tid': 13,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [13],
#     'lr': [13],
#     'max_depth': [13],
#     'min_samples_leaf': [13],
#     'subsample': [13]},
#    'vals': {'colsample_bytree': [17],
#     'lr': [1],
#     'max_depth': [3],
#     'min_samples_leaf': [1],
#     'subsample': [8]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 19, 59, 30, 866000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 1, 2, 666000)},
#  {'state': 2,
#   'tid': 14,
#   'spec': None,
#   'result': {'loss': -0.39279742447165017, 'status': 'ok'},
#   'misc': {'tid': 14,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [14],
#     'lr': [14],
#     'max_depth': [14],
#     'min_samples_leaf': [14],
#     'subsample': [14]},
#    'vals': {'colsample_bytree': [5],
#     'lr': [17],
#     'max_depth': [5],
#     'min_samples_leaf': [1],
#     'subsample': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 1, 2, 672000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 1, 53, 963000)},
#  {'state': 2,
#   'tid': 15,
#   'spec': None,
#   'result': {'loss': -0.3829088434283376, 'status': 'ok'},
#   'misc': {'tid': 15,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [15],
#     'lr': [15],
#     'max_depth': [15],
#     'min_samples_leaf': [15],
#     'subsample': [15]},
#    'vals': {'colsample_bytree': [2],
#     'lr': [4],
#     'max_depth': [1],
#     'min_samples_leaf': [2],
#     'subsample': [15]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 1, 53, 969000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 2, 48, 463000)},
#  {'state': 2,
#   'tid': 16,
#   'spec': None,
#   'result': {'loss': -0.405128033096024, 'status': 'ok'},
#   'misc': {'tid': 16,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [16],
#     'lr': [16],
#     'max_depth': [16],
#     'min_samples_leaf': [16],
#     'subsample': [16]},
#    'vals': {'colsample_bytree': [17],
#     'lr': [4],
#     'max_depth': [4],
#     'min_samples_leaf': [5],
#     'subsample': [16]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 2, 48, 474000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 5, 29, 381000)},
#  {'state': 2,
#   'tid': 17,
#   'spec': None,
#   'result': {'loss': -0.40956410616021094, 'status': 'ok'},
#   'misc': {'tid': 17,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [17],
#     'lr': [17],
#     'max_depth': [17],
#     'min_samples_leaf': [17],
#     'subsample': [17]},
#    'vals': {'colsample_bytree': [9],
#     'lr': [3],
#     'max_depth': [2],
#     'min_samples_leaf': [5],
#     'subsample': [15]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 5, 29, 388000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 6, 45, 716000)},
#  {'state': 2,
#   'tid': 18,
#   'spec': None,
#   'result': {'loss': -0.40521521914264474, 'status': 'ok'},
#   'misc': {'tid': 18,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [18],
#     'lr': [18],
#     'max_depth': [18],
#     'min_samples_leaf': [18],
#     'subsample': [18]},
#    'vals': {'colsample_bytree': [11],
#     'lr': [11],
#     'max_depth': [3],
#     'min_samples_leaf': [1],
#     'subsample': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 6, 45, 723000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 7, 43, 876000)},
#  {'state': 2,
#   'tid': 19,
#   'spec': None,
#   'result': {'loss': -0.3823853309254734, 'status': 'ok'},
#   'misc': {'tid': 19,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [19],
#     'lr': [19],
#     'max_depth': [19],
#     'min_samples_leaf': [19],
#     'subsample': [19]},
#    'vals': {'colsample_bytree': [1],
#     'lr': [2],
#     'max_depth': [3],
#     'min_samples_leaf': [2],
#     'subsample': [13]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 7, 43, 887000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 8, 37, 304000)},
#  {'state': 2,
#   'tid': 20,
#   'spec': None,
#   'result': {'loss': -0.41075651533294405, 'status': 'ok'},
#   'misc': {'tid': 20,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [20],
#     'lr': [20],
#     'max_depth': [20],
#     'min_samples_leaf': [20],
#     'subsample': [20]},
#    'vals': {'colsample_bytree': [12],
#     'lr': [10],
#     'max_depth': [2],
#     'min_samples_leaf': [3],
#     'subsample': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 8, 37, 314000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 9, 44, 245000)},
#  {'state': 2,
#   'tid': 21,
#   'spec': None,
#   'result': {'loss': -0.4128736877372661, 'status': 'ok'},
#   'misc': {'tid': 21,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [21],
#     'lr': [21],
#     'max_depth': [21],
#     'min_samples_leaf': [21],
#     'subsample': [21]},
#    'vals': {'colsample_bytree': [12],
#     'lr': [5],
#     'max_depth': [5],
#     'min_samples_leaf': [3],
#     'subsample': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 9, 44, 255000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 10, 59, 97000)},
#  {'state': 2,
#   'tid': 22,
#   'spec': None,
#   'result': {'loss': -0.4215634761017064, 'status': 'ok'},
#   'misc': {'tid': 22,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [22],
#     'lr': [22],
#     'max_depth': [22],
#     'min_samples_leaf': [22],
#     'subsample': [22]},
#    'vals': {'colsample_bytree': [13],
#     'lr': [10],
#     'max_depth': [4],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 10, 59, 113000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 12, 8, 296000)},
#  {'state': 2,
#   'tid': 23,
#   'spec': None,
#   'result': {'loss': -0.42894589222890045, 'status': 'ok'},
#   'misc': {'tid': 23,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [23],
#     'lr': [23],
#     'max_depth': [23],
#     'min_samples_leaf': [23],
#     'subsample': [23]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [18],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 12, 8, 306000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 13, 11, 314000)},
#  {'state': 2,
#   'tid': 24,
#   'spec': None,
#   'result': {'loss': -0.42894589222890045, 'status': 'ok'},
#   'misc': {'tid': 24,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [24],
#     'lr': [24],
#     'max_depth': [24],
#     'min_samples_leaf': [24],
#     'subsample': [24]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [18],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 13, 11, 323000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 14, 21, 304000)},
#  {'state': 2,
#   'tid': 25,
#   'spec': None,
#   'result': {'loss': -0.42894589222890045, 'status': 'ok'},
#   'misc': {'tid': 25,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [25],
#     'lr': [25],
#     'max_depth': [25],
#     'min_samples_leaf': [25],
#     'subsample': [25]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [18],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 14, 21, 313000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 15, 25, 178000)},
#  {'state': 2,
#   'tid': 26,
#   'spec': None,
#   'result': {'loss': -0.42464821520126855, 'status': 'ok'},
#   'misc': {'tid': 26,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [26],
#     'lr': [26],
#     'max_depth': [26],
#     'min_samples_leaf': [26],
#     'subsample': [26]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [18],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [14]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 15, 25, 193000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 17, 27, 411000)},
#  {'state': 2,
#   'tid': 27,
#   'spec': None,
#   'result': {'loss': -0.4041890428311191, 'status': 'ok'},
#   'misc': {'tid': 27,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [27],
#     'lr': [27],
#     'max_depth': [27],
#     'min_samples_leaf': [27],
#     'subsample': [27]},
#    'vals': {'colsample_bytree': [10],
#     'lr': [13],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 17, 27, 428000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 18, 33, 927000)},
#  {'state': 2,
#   'tid': 28,
#   'spec': None,
#   'result': {'loss': -0.420178242688059, 'status': 'ok'},
#   'misc': {'tid': 28,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [28],
#     'lr': [28],
#     'max_depth': [28],
#     'min_samples_leaf': [28],
#     'subsample': [28]},
#    'vals': {'colsample_bytree': [7],
#     'lr': [18],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [12]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 18, 33, 944000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 19, 59, 181000)},
#  {'state': 2,
#   'tid': 29,
#   'spec': None,
#   'result': {'loss': -0.3979227362823605, 'status': 'ok'},
#   'misc': {'tid': 29,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [29],
#     'lr': [29],
#     'max_depth': [29],
#     'min_samples_leaf': [29],
#     'subsample': [29]},
#    'vals': {'colsample_bytree': [4],
#     'lr': [6],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [10]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 19, 59, 198000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 21, 5, 223000)},
#  {'state': 2,
#   'tid': 30,
#   'spec': None,
#   'result': {'loss': -0.4153512847691043, 'status': 'ok'},
#   'misc': {'tid': 30,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [30],
#     'lr': [30],
#     'max_depth': [30],
#     'min_samples_leaf': [30],
#     'subsample': [30]},
#    'vals': {'colsample_bytree': [15],
#     'lr': [8],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [6]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 21, 5, 234000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 22, 28, 397000)},
#  {'state': 2,
#   'tid': 31,
#   'spec': None,
#   'result': {'loss': -0.42894589222890045, 'status': 'ok'},
#   'misc': {'tid': 31,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [31],
#     'lr': [31],
#     'max_depth': [31],
#     'min_samples_leaf': [31],
#     'subsample': [31]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [18],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 22, 28, 406000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 23, 36, 943000)},
#  {'state': 2,
#   'tid': 32,
#   'spec': None,
#   'result': {'loss': -0.3388218297330663, 'status': 'ok'},
#   'misc': {'tid': 32,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [32],
#     'lr': [32],
#     'max_depth': [32],
#     'min_samples_leaf': [32],
#     'subsample': [32]},
#    'vals': {'colsample_bytree': [0],
#     'lr': [15],
#     'max_depth': [2],
#     'min_samples_leaf': [4],
#     'subsample': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 23, 36, 953000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 24, 19, 931000)},
#  {'state': 2,
#   'tid': 33,
#   'spec': None,
#   'result': {'loss': -0.3652924030555193, 'status': 'ok'},
#   'misc': {'tid': 33,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [33],
#     'lr': [33],
#     'max_depth': [33],
#     'min_samples_leaf': [33],
#     'subsample': [33]},
#    'vals': {'colsample_bytree': [3],
#     'lr': [0],
#     'max_depth': [0],
#     'min_samples_leaf': [0],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 24, 19, 949000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 25, 7, 335000)},
#  {'state': 2,
#   'tid': 34,
#   'spec': None,
#   'result': {'loss': -0.39771867132498023, 'status': 'ok'},
#   'misc': {'tid': 34,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [34],
#     'lr': [34],
#     'max_depth': [34],
#     'min_samples_leaf': [34],
#     'subsample': [34]},
#    'vals': {'colsample_bytree': [6],
#     'lr': [14],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 25, 7, 352000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 26, 7, 521000)},
#  {'state': 2,
#   'tid': 35,
#   'spec': None,
#   'result': {'loss': -0.4042862225548403, 'status': 'ok'},
#   'misc': {'tid': 35,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [35],
#     'lr': [35],
#     'max_depth': [35],
#     'min_samples_leaf': [35],
#     'subsample': [35]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [18],
#     'max_depth': [0],
#     'min_samples_leaf': [3],
#     'subsample': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 26, 7, 531000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 26, 53, 553000)},
#  {'state': 2,
#   'tid': 36,
#   'spec': None,
#   'result': {'loss': -0.41864062311867317, 'status': 'ok'},
#   'misc': {'tid': 36,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [36],
#     'lr': [36],
#     'max_depth': [36],
#     'min_samples_leaf': [36],
#     'subsample': [36]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [9],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [9]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 26, 53, 563000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 28, 36, 76000)},
#  {'state': 2,
#   'tid': 37,
#   'spec': None,
#   'result': {'loss': -0.4010515747509984, 'status': 'ok'},
#   'misc': {'tid': 37,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [37],
#     'lr': [37],
#     'max_depth': [37],
#     'min_samples_leaf': [37],
#     'subsample': [37]},
#    'vals': {'colsample_bytree': [8],
#     'lr': [7],
#     'max_depth': [5],
#     'min_samples_leaf': [2],
#     'subsample': [11]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 28, 36, 87000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 30, 3, 350000)},
#  {'state': 2,
#   'tid': 38,
#   'spec': None,
#   'result': {'loss': -0.40314546266188, 'status': 'ok'},
#   'misc': {'tid': 38,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [38],
#     'lr': [38],
#     'max_depth': [38],
#     'min_samples_leaf': [38],
#     'subsample': [38]},
#    'vals': {'colsample_bytree': [15],
#     'lr': [18],
#     'max_depth': [2],
#     'min_samples_leaf': [4],
#     'subsample': [17]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 30, 3, 360000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 31, 49, 762000)},
#  {'state': 2,
#   'tid': 39,
#   'spec': None,
#   'result': {'loss': -0.3981961872495129, 'status': 'ok'},
#   'misc': {'tid': 39,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [39],
#     'lr': [39],
#     'max_depth': [39],
#     'min_samples_leaf': [39],
#     'subsample': [39]},
#    'vals': {'colsample_bytree': [16],
#     'lr': [16],
#     'max_depth': [1],
#     'min_samples_leaf': [0],
#     'subsample': [7]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 31, 49, 772000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 32, 57, 467000)},
#  {'state': 2,
#   'tid': 40,
#   'spec': None,
#   'result': {'loss': -0.40100504510529705, 'status': 'ok'},
#   'misc': {'tid': 40,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [40],
#     'lr': [40],
#     'max_depth': [40],
#     'min_samples_leaf': [40],
#     'subsample': [40]},
#    'vals': {'colsample_bytree': [10],
#     'lr': [12],
#     'max_depth': [0],
#     'min_samples_leaf': [5],
#     'subsample': [6]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 32, 57, 478000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 33, 46, 666000)},
#  {'state': 2,
#   'tid': 41,
#   'spec': None,
#   'result': {'loss': -0.3683893943716093, 'status': 'ok'},
#   'misc': {'tid': 41,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [41],
#     'lr': [41],
#     'max_depth': [41],
#     'min_samples_leaf': [41],
#     'subsample': [41]},
#    'vals': {'colsample_bytree': [0],
#     'lr': [8],
#     'max_depth': [5],
#     'min_samples_leaf': [1],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 33, 46, 676000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 34, 33, 302000)},
#  {'state': 2,
#   'tid': 42,
#   'spec': None,
#   'result': {'loss': -0.3789867422712945, 'status': 'ok'},
#   'misc': {'tid': 42,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [42],
#     'lr': [42],
#     'max_depth': [42],
#     'min_samples_leaf': [42],
#     'subsample': [42]},
#    'vals': {'colsample_bytree': [4],
#     'lr': [13],
#     'max_depth': [1],
#     'min_samples_leaf': [0],
#     'subsample': [13]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 34, 33, 312000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 35, 33, 531000)},
#  {'state': 2,
#   'tid': 43,
#   'spec': None,
#   'result': {'loss': -0.3996702435564215, 'status': 'ok'},
#   'misc': {'tid': 43,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [43],
#     'lr': [43],
#     'max_depth': [43],
#     'min_samples_leaf': [43],
#     'subsample': [43]},
#    'vals': {'colsample_bytree': [6],
#     'lr': [17],
#     'max_depth': [4],
#     'min_samples_leaf': [4],
#     'subsample': [14]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 35, 33, 548000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 36, 55, 445000)},
#  {'state': 2,
#   'tid': 44,
#   'spec': None,
#   'result': {'loss': -0.40670087209152556, 'status': 'ok'},
#   'misc': {'tid': 44,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [44],
#     'lr': [44],
#     'max_depth': [44],
#     'min_samples_leaf': [44],
#     'subsample': [44]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [11],
#     'max_depth': [5],
#     'min_samples_leaf': [2],
#     'subsample': [8]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 36, 55, 462000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 38, 29, 321000)},
#  {'state': 2,
#   'tid': 45,
#   'spec': None,
#   'result': {'loss': -0.3959184348963184, 'status': 'ok'},
#   'misc': {'tid': 45,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [45],
#     'lr': [45],
#     'max_depth': [45],
#     'min_samples_leaf': [45],
#     'subsample': [45]},
#    'vals': {'colsample_bytree': [7],
#     'lr': [1],
#     'max_depth': [0],
#     'min_samples_leaf': [3],
#     'subsample': [10]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 38, 29, 332000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 39, 23, 627000)},
#  {'state': 2,
#   'tid': 46,
#   'spec': None,
#   'result': {'loss': -0.3902251696962638, 'status': 'ok'},
#   'misc': {'tid': 46,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [46],
#     'lr': [46],
#     'max_depth': [46],
#     'min_samples_leaf': [46],
#     'subsample': [46]},
#    'vals': {'colsample_bytree': [3],
#     'lr': [14],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [12]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 39, 23, 644000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 40, 27, 502000)},
#  {'state': 2,
#   'tid': 47,
#   'spec': None,
#   'result': {'loss': -0.3807802206497286, 'status': 'ok'},
#   'misc': {'tid': 47,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [47],
#     'lr': [47],
#     'max_depth': [47],
#     'min_samples_leaf': [47],
#     'subsample': [47]},
#    'vals': {'colsample_bytree': [9],
#     'lr': [6],
#     'max_depth': [3],
#     'min_samples_leaf': [1],
#     'subsample': [16]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 40, 27, 512000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 42, 3, 810000)},
#  {'state': 2,
#   'tid': 48,
#   'spec': None,
#   'result': {'loss': -0.3854464799277108, 'status': 'ok'},
#   'misc': {'tid': 48,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [48],
#     'lr': [48],
#     'max_depth': [48],
#     'min_samples_leaf': [48],
#     'subsample': [48]},
#    'vals': {'colsample_bytree': [2],
#     'lr': [15],
#     'max_depth': [2],
#     'min_samples_leaf': [5],
#     'subsample': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 42, 3, 828000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 42, 48, 271000)},
#  {'state': 2,
#   'tid': 49,
#   'spec': None,
#   'result': {'loss': -0.35570190986929845, 'status': 'ok'},
#   'misc': {'tid': 49,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [49],
#     'lr': [49],
#     'max_depth': [49],
#     'min_samples_leaf': [49],
#     'subsample': [49]},
#    'vals': {'colsample_bytree': [8],
#     'lr': [3],
#     'max_depth': [1],
#     'min_samples_leaf': [0],
#     'subsample': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 42, 48, 280000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 43, 37, 801000)},
#  {'state': 2,
#   'tid': 50,
#   'spec': None,
#   'result': {'loss': -0.38302925122336545, 'status': 'ok'},
#   'misc': {'tid': 50,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [50],
#     'lr': [50],
#     'max_depth': [50],
#     'min_samples_leaf': [50],
#     'subsample': [50]},
#    'vals': {'colsample_bytree': [1],
#     'lr': [0],
#     'max_depth': [4],
#     'min_samples_leaf': [2],
#     'subsample': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 43, 37, 812000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 44, 20, 719000)},
#  {'state': 2,
#   'tid': 51,
#   'spec': None,
#   'result': {'loss': -0.4009318430958631, 'status': 'ok'},
#   'misc': {'tid': 51,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [51],
#     'lr': [51],
#     'max_depth': [51],
#     'min_samples_leaf': [51],
#     'subsample': [51]},
#    'vals': {'colsample_bytree': [5],
#     'lr': [5],
#     'max_depth': [3],
#     'min_samples_leaf': [4],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 44, 20, 730000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 45, 7, 917000)},
#  {'state': 2,
#   'tid': 52,
#   'spec': None,
#   'result': {'loss': -0.41864062311867317, 'status': 'ok'},
#   'misc': {'tid': 52,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [52],
#     'lr': [52],
#     'max_depth': [52],
#     'min_samples_leaf': [52],
#     'subsample': [52]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [7],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [9]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 45, 7, 935000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 46, 46, 829000)},
#  {'state': 2,
#   'tid': 53,
#   'spec': None,
#   'result': {'loss': -0.4091282626280696, 'status': 'ok'},
#   'misc': {'tid': 53,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [53],
#     'lr': [53],
#     'max_depth': [53],
#     'min_samples_leaf': [53],
#     'subsample': [53]},
#    'vals': {'colsample_bytree': [17],
#     'lr': [18],
#     'max_depth': [5],
#     'min_samples_leaf': [3],
#     'subsample': [15]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 46, 46, 848000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 49, 34, 616000)},
#  {'state': 2,
#   'tid': 54,
#   'spec': None,
#   'result': {'loss': -0.3954299959347024, 'status': 'ok'},
#   'misc': {'tid': 54,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [54],
#     'lr': [54],
#     'max_depth': [54],
#     'min_samples_leaf': [54],
#     'subsample': [54]},
#    'vals': {'colsample_bytree': [11],
#     'lr': [2],
#     'max_depth': [4],
#     'min_samples_leaf': [1],
#     'subsample': [11]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 49, 34, 633000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 51, 16, 551000)},
#  {'state': 2,
#   'tid': 55,
#   'spec': None,
#   'result': {'loss': -0.41145101066444467, 'status': 'ok'},
#   'misc': {'tid': 55,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [55],
#     'lr': [55],
#     'max_depth': [55],
#     'min_samples_leaf': [55],
#     'subsample': [55]},
#    'vals': {'colsample_bytree': [13],
#     'lr': [1],
#     'max_depth': [2],
#     'min_samples_leaf': [5],
#     'subsample': [7]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 51, 16, 569000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 52, 26, 525000)},
#  {'state': 2,
#   'tid': 56,
#   'spec': None,
#   'result': {'loss': -0.4022679385846495, 'status': 'ok'},
#   'misc': {'tid': 56,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [56],
#     'lr': [56],
#     'max_depth': [56],
#     'min_samples_leaf': [56],
#     'subsample': [56]},
#    'vals': {'colsample_bytree': [16],
#     'lr': [16],
#     'max_depth': [1],
#     'min_samples_leaf': [5],
#     'subsample': [8]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 52, 26, 535000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 53, 37, 804000)},
#  {'state': 2,
#   'tid': 57,
#   'spec': None,
#   'result': {'loss': -0.40189755096476676, 'status': 'ok'},
#   'misc': {'tid': 57,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [57],
#     'lr': [57],
#     'max_depth': [57],
#     'min_samples_leaf': [57],
#     'subsample': [57]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [17],
#     'max_depth': [0],
#     'min_samples_leaf': [2],
#     'subsample': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 53, 37, 814000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 54, 27, 255000)},
#  {'state': 2,
#   'tid': 58,
#   'spec': None,
#   'result': {'loss': -0.3967559475760077, 'status': 'ok'},
#   'misc': {'tid': 58,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [58],
#     'lr': [58],
#     'max_depth': [58],
#     'min_samples_leaf': [58],
#     'subsample': [58]},
#    'vals': {'colsample_bytree': [9],
#     'lr': [9],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [17]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 54, 27, 268000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 56, 22, 923000)},
#  {'state': 2,
#   'tid': 59,
#   'spec': None,
#   'result': {'loss': -0.40246975780095706, 'status': 'ok'},
#   'misc': {'tid': 59,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [59],
#     'lr': [59],
#     'max_depth': [59],
#     'min_samples_leaf': [59],
#     'subsample': [59]},
#    'vals': {'colsample_bytree': [12],
#     'lr': [18],
#     'max_depth': [3],
#     'min_samples_leaf': [3],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 56, 22, 935000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 57, 25, 990000)},
#  {'state': 2,
#   'tid': 60,
#   'spec': None,
#   'result': {'loss': -0.39458534637676, 'status': 'ok'},
#   'misc': {'tid': 60,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [60],
#     'lr': [60],
#     'max_depth': [60],
#     'min_samples_leaf': [60],
#     'subsample': [60]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [12],
#     'max_depth': [5],
#     'min_samples_leaf': [1],
#     'subsample': [13]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 57, 26),
#   'refresh_time': datetime.datetime(2021, 7, 14, 20, 59, 37, 681000)},
#  {'state': 2,
#   'tid': 61,
#   'spec': None,
#   'result': {'loss': -0.38245383266136573, 'status': 'ok'},
#   'misc': {'tid': 61,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [61],
#     'lr': [61],
#     'max_depth': [61],
#     'min_samples_leaf': [61],
#     'subsample': [61]},
#    'vals': {'colsample_bytree': [2],
#     'lr': [4],
#     'max_depth': [5],
#     'min_samples_leaf': [4],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 20, 59, 37, 697000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 0, 28, 315000)},
#  {'state': 2,
#   'tid': 62,
#   'spec': None,
#   'result': {'loss': -0.3533194033799449, 'status': 'ok'},
#   'misc': {'tid': 62,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [62],
#     'lr': [62],
#     'max_depth': [62],
#     'min_samples_leaf': [62],
#     'subsample': [62]},
#    'vals': {'colsample_bytree': [5],
#     'lr': [11],
#     'max_depth': [4],
#     'min_samples_leaf': [0],
#     'subsample': [16]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 0, 28, 326000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 1, 54, 570000)},
#  {'state': 2,
#   'tid': 63,
#   'spec': None,
#   'result': {'loss': -0.40922617419741325, 'status': 'ok'},
#   'misc': {'tid': 63,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [63],
#     'lr': [63],
#     'max_depth': [63],
#     'min_samples_leaf': [63],
#     'subsample': [63]},
#    'vals': {'colsample_bytree': [10],
#     'lr': [10],
#     'max_depth': [2],
#     'min_samples_leaf': [5],
#     'subsample': [14]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 1, 54, 581000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 3, 20, 675000)},
#  {'state': 2,
#   'tid': 64,
#   'spec': None,
#   'result': {'loss': -0.414444315530895, 'status': 'ok'},
#   'misc': {'tid': 64,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [64],
#     'lr': [64],
#     'max_depth': [64],
#     'min_samples_leaf': [64],
#     'subsample': [64]},
#    'vals': {'colsample_bytree': [7],
#     'lr': [18],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 3, 20, 692000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 4, 25, 738000)},
#  {'state': 2,
#   'tid': 65,
#   'spec': None,
#   'result': {'loss': -0.42894589222890045, 'status': 'ok'},
#   'misc': {'tid': 65,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [65],
#     'lr': [65],
#     'max_depth': [65],
#     'min_samples_leaf': [65],
#     'subsample': [65]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [18],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 4, 25, 752000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 5, 41, 775000)},
#  {'state': 2,
#   'tid': 66,
#   'spec': None,
#   'result': {'loss': -0.42894589222890045, 'status': 'ok'},
#   'misc': {'tid': 66,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [66],
#     'lr': [66],
#     'max_depth': [66],
#     'min_samples_leaf': [66],
#     'subsample': [66]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [18],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 5, 41, 788000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 6, 53, 266000)},
#  {'state': 2,
#   'tid': 67,
#   'spec': None,
#   'result': {'loss': -0.42894589222890045, 'status': 'ok'},
#   'misc': {'tid': 67,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [67],
#     'lr': [67],
#     'max_depth': [67],
#     'min_samples_leaf': [67],
#     'subsample': [67]},
#    'vals': {'colsample_bytree': [14],
#     'lr': [18],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 6, 53, 278000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 8, 6, 279000)},
#  {'state': 2,
#   'tid': 68,
#   'spec': None,
#   'result': {'loss': -0.4318346664243743, 'status': 'ok'},
#   'misc': {'tid': 68,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [68],
#     'lr': [68],
#     'max_depth': [68],
#     'min_samples_leaf': [68],
#     'subsample': [68]},
#    'vals': {'colsample_bytree': [15],
#     'lr': [3],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 8, 6, 292000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 9, 19, 328000)},
#  {'state': 2,
#   'tid': 69,
#   'spec': None,
#   'result': {'loss': -0.4318346664243743, 'status': 'ok'},
#   'misc': {'tid': 69,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [69],
#     'lr': [69],
#     'max_depth': [69],
#     'min_samples_leaf': [69],
#     'subsample': [69]},
#    'vals': {'colsample_bytree': [15],
#     'lr': [3],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 9, 19, 339000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 10, 32, 495000)},
#  {'state': 2,
#   'tid': 70,
#   'spec': None,
#   'result': {'loss': -0.4183887694644179, 'status': 'ok'},
#   'misc': {'tid': 70,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [70],
#     'lr': [70],
#     'max_depth': [70],
#     'min_samples_leaf': [70],
#     'subsample': [70]},
#    'vals': {'colsample_bytree': [15],
#     'lr': [3],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [12]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 10, 32, 510000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 12, 44, 892000)},
#  {'state': 2,
#   'tid': 71,
#   'spec': None,
#   'result': {'loss': -0.4153512847691043, 'status': 'ok'},
#   'misc': {'tid': 71,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [71],
#     'lr': [71],
#     'max_depth': [71],
#     'min_samples_leaf': [71],
#     'subsample': [71]},
#    'vals': {'colsample_bytree': [15],
#     'lr': [3],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [6]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 12, 44, 914000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 14, 19, 520000)},
#  {'state': 2,
#   'tid': 72,
#   'spec': None,
#   'result': {'loss': -0.4138055537822837, 'status': 'ok'},
#   'misc': {'tid': 72,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [72],
#     'lr': [72],
#     'max_depth': [72],
#     'min_samples_leaf': [72],
#     'subsample': [72]},
#    'vals': {'colsample_bytree': [15],
#     'lr': [3],
#     'max_depth': [3],
#     'min_samples_leaf': [5],
#     'subsample': [10]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 14, 19, 533000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 15, 56, 604000)},
#  {'state': 2,
#   'tid': 73,
#   'spec': None,
#   'result': {'loss': -0.4140817130250661, 'status': 'ok'},
#   'misc': {'tid': 73,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [73],
#     'lr': [73],
#     'max_depth': [73],
#     'min_samples_leaf': [73],
#     'subsample': [73]},
#    'vals': {'colsample_bytree': [15],
#     'lr': [3],
#     'max_depth': [0],
#     'min_samples_leaf': [2],
#     'subsample': [15]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 15, 56, 617000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 17, 14, 14000)},
#  {'state': 2,
#   'tid': 74,
#   'spec': None,
#   'result': {'loss': -0.4093073174249307, 'status': 'ok'},
#   'misc': {'tid': 74,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [74],
#     'lr': [74],
#     'max_depth': [74],
#     'min_samples_leaf': [74],
#     'subsample': [74]},
#    'vals': {'colsample_bytree': [15],
#     'lr': [3],
#     'max_depth': [1],
#     'min_samples_leaf': [5],
#     'subsample': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 17, 14, 37000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 18, 15, 756000)},
#  {'state': 2,
#   'tid': 75,
#   'spec': None,
#   'result': {'loss': -0.4108248362591764, 'status': 'ok'},
#   'misc': {'tid': 75,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [75],
#     'lr': [75],
#     'max_depth': [75],
#     'min_samples_leaf': [75],
#     'subsample': [75]},
#    'vals': {'colsample_bytree': [15],
#     'lr': [3],
#     'max_depth': [5],
#     'min_samples_leaf': [3],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 18, 15, 782000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 19, 31, 516000)},
#  {'state': 2,
#   'tid': 76,
#   'spec': None,
#   'result': {'loss': -0.3745758409578189, 'status': 'ok'},
#   'misc': {'tid': 76,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [76],
#     'lr': [76],
#     'max_depth': [76],
#     'min_samples_leaf': [76],
#     'subsample': [76]},
#    'vals': {'colsample_bytree': [4],
#     'lr': [8],
#     'max_depth': [5],
#     'min_samples_leaf': [0],
#     'subsample': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 19, 31, 528000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 20, 27, 5000)},
#  {'state': 2,
#   'tid': 77,
#   'spec': None,
#   'result': {'loss': -0.37494926072462104, 'status': 'ok'},
#   'misc': {'tid': 77,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [77],
#     'lr': [77],
#     'max_depth': [77],
#     'min_samples_leaf': [77],
#     'subsample': [77]},
#    'vals': {'colsample_bytree': [0],
#     'lr': [5],
#     'max_depth': [5],
#     'min_samples_leaf': [4],
#     'subsample': [9]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 20, 27, 19000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 21, 24, 630000)},
#  {'state': 2,
#   'tid': 78,
#   'spec': None,
#   'result': {'loss': -0.421417792450865, 'status': 'ok'},
#   'misc': {'tid': 78,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [78],
#     'lr': [78],
#     'max_depth': [78],
#     'min_samples_leaf': [78],
#     'subsample': [78]},
#    'vals': {'colsample_bytree': [6],
#     'lr': [13],
#     'max_depth': [5],
#     'min_samples_leaf': [5],
#     'subsample': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 21, 24, 644000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 22, 20, 988000)},
#  {'state': 2,
#   'tid': 79,
#   'spec': None,
#   'result': {'loss': -0.3688823279494985, 'status': 'ok'},
#   'misc': {'tid': 79,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [79],
#     'lr': [79],
#     'max_depth': [79],
#     'min_samples_leaf': [79],
#     'subsample': [79]},
#    'vals': {'colsample_bytree': [1],
#     'lr': [6],
#     'max_depth': [2],
#     'min_samples_leaf': [1],
#     'subsample': [11]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 22, 21, 1000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 23, 15, 362000)},
#  {'state': 2,
#   'tid': 80,
#   'spec': None,
#   'result': {'loss': -0.41050435573304644, 'status': 'ok'},
#   'misc': {'tid': 80,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [80],
#     'lr': [80],
#     'max_depth': [80],
#     'min_samples_leaf': [80],
#     'subsample': [80]},
#    'vals': {'colsample_bytree': [17],
#     'lr': [2],
#     'max_depth': [0],
#     'min_samples_leaf': [5],
#     'subsample': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 23, 15, 383000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 24, 4, 833000)},
#  {'state': 2,
#   'tid': 81,
#   'spec': None,
#   'result': {'loss': -0.3972091395930002, 'status': 'ok'},
#   'misc': {'tid': 81,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [81],
#     'lr': [81],
#     'max_depth': [81],
#     'min_samples_leaf': [81],
#     'subsample': [81]},
#    'vals': {'colsample_bytree': [3],
#     'lr': [15],
#     'max_depth': [4],
#     'min_samples_leaf': [5],
#     'subsample': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 24, 4, 846000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 25, 2, 599000)},
#  {'state': 1,
#   'tid': 82,
#   'spec': None,
#   'result': {'status': 'new'},
#   'misc': {'tid': 82,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'colsample_bytree': [82],
#     'lr': [82],
#     'max_depth': [82],
#     'min_samples_leaf': [82],
#     'subsample': [82]},
#    'vals': {'colsample_bytree': [8],
#     'lr': [0],
#     'max_depth': [3],
#     'min_samples_leaf': [2],
#     'subsample': [7]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2021, 7, 14, 21, 25, 2, 618000),
#   'refresh_time': datetime.datetime(2021, 7, 14, 21, 25, 2, 618000)}]

# %%
# best_trials

# %%
top_res_list = []
for bt in best_trials:
    d = bt['misc']['vals']
    d = {k:v[0] for k,v in d.items()}
    
    ddd = dict(zip(['lr','subsample', 'colsample_bytree', 'max_depth','min_samples_leaf'], 
             hyperopt.space_eval(space, d)))
    ddd['score'] = bt['result']['loss']
    
    top_res_list.append(ddd)

# %%
top_res_list
# Out:
# [{'lr': 0.45,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 7,
#   'score': -0.4319659896309627},
#  {'lr': 0.45,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 7,
#   'score': -0.4319659896309627},
#  {'lr': 0.15000000000000002,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 7,
#   'score': -0.4319659896309627},
#  {'lr': 0.45,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 7,
#   'score': -0.4319659896309627},
#  {'lr': 0.7000000000000001,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 7,
#   'score': -0.4319659896309627},
#  {'lr': 0.45,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 7,
#   'score': -0.4319659896309627},
#  {'lr': 0.6000000000000001,
#   'subsample': 0.25000000000000006,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 11,
#   'score': -0.43088607288495573},
#  {'lr': 0.6000000000000001,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 9,
#   'score': -0.42930617408426214},
#  {'lr': 0.6000000000000001,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 9,
#   'score': -0.42930617408426214},
#  {'lr': 0.6000000000000001,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 9,
#   'score': -0.42930617408426214},
#  {'lr': 0.6000000000000001,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 9,
#   'score': -0.42930617408426214},
#  {'lr': 0.6000000000000001,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 9,
#   'score': -0.42930617408426214},
#  {'lr': 0.6000000000000001,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 9,
#   'score': -0.42930617408426214},
#  {'lr': 0.6000000000000001,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 9,
#   'score': -0.42930617408426214},
#  {'lr': 0.6000000000000001,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 9,
#   'score': -0.42930617408426214},
#  {'lr': 0.2,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 9,
#   'score': -0.42930617408426214},
#  {'lr': 0.45,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 9,
#   'score': -0.42930617408426214},
#  {'lr': 0.7000000000000001,
#   'subsample': 0.20000000000000004,
#   'colsample_bytree': 0.7500000000000002,
#   'max_depth': 9,
#   'min_samples_leaf': 11,
#   'score': -0.42910805024226095},
#  {'lr': 0.6000000000000001,
#   'subsample': 0.3500000000000001,
#   'colsample_bytree': 0.9000000000000002,
#   'max_depth': 11,
#   'min_samples_leaf': 7,
#   'score': -0.42849094554831607},
#  {'lr': 0.2,
#   'subsample': 0.15000000000000002,
#   'colsample_bytree': 0.9500000000000003,
#   'max_depth': 13,
#   'min_samples_leaf': 13,
#   'score': -0.42835772949857864}]
